# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

# %%
#  Define the instruments to download
companies_dict = {
    'Amazon':'AMZN',
    'Apple':'AAPL',
    'Walgreen' : 'WBA',
    'Northrom Grumman':'NOC',
    'Boeing':'BA',
    'Lockheed Martin':'LMT',
    'McDonalds':'MCD',
    'Intel': 'INTC',
    'Navistar':'NAV',
    'IBM':'IBM',
    'Texas Instruments':'TXN',
    'MasterCard':'MA',
    'Microsoft':'MSFT',
    'General Electrics':'GE',
    'Symantec':'SYNC',
    'American Express':'AXP',
    'Pepsi':'PEP',
    'Coca Cola':'KO',
    'Johnson & Johnson':'JNJ',
    'Toyata':'TM',
    'Honda':'HMC',
    'Mistubishi':'MSBHY',
    'Sony':'SNE',
    'Exxon':'XOM',
    'Chevron':'CVX',
    'Valero Energy':'VLO',
    'Ford':'F',
    'Bank of America':'BAC'}

companies = sorted(companies_dict.items(), key=lambda x:x[1])

print(companies)
# Out:
# [('Apple', 'AAPL'), ('Amazon', 'AMZN'), ('American Express', 'AXP'), ('Boeing', 'BA'), ('Bank of America', 'BAC'), ('Chevron', 'CVX'), ('Ford', 'F'), ('General Electrics', 'GE'), ('Honda', 'HMC'), ('IBM', 'IBM'), ('Intel', 'INTC'), ('Johnson & Johnson', 'JNJ'), ('Coca Cola', 'KO'), ('Lockheed Martin', 'LMT'), ('MasterCard', 'MA'), ('McDonalds', 'MCD'), ('Mistubishi', 'MSBHY'), ('Microsoft', 'MSFT'), ('Navistar', 'NAV'), ('Northrom Grumman', 'NOC'), ('Pepsi', 'PEP'), ('Sony', 'SNE'), ('Symantec', 'SYNC'), ('Toyata', 'TM'), ('Texas Instruments', 'TXN'), ('Valero Energy', 'VLO'), ('Walgreen', 'WBA'), ('Exxon', 'XOM')]

# %%
# Define which online source to use
source = "yahoo"
# define the start and end dates
start_date = '2015-01-01'
end_date = '2017-12-31'
# use pandas_reader to load the desire stock data
values = [x for x in companies_dict.values()]
print(values)
panel_data = data.DataReader(values,data_source=source,start= start_date,end =end_date)

# Print Axes labels
# Out:
# ['AMZN', 'AAPL', 'WBA', 'NOC', 'BA', 'LMT', 'MCD', 'INTC', 'NAV', 'IBM', 'TXN', 'MA', 'MSFT', 'GE', 'SYNC', 'AXP', 'PEP', 'KO', 'JNJ', 'TM', 'HMC', 'MSBHY', 'SNE', 'XOM', 'CVX', 'VLO', 'F', 'BAC']

# %%
panel_data.describe()
# Out:
# Attributes        High               ...   Adj Close
# Symbols           AAPL         AMZN  ...         WBA         XOM
# count       756.000000   756.000000  ...  756.000000  756.000000
# mean        125.975291   720.298267  ...   76.596664   74.454551
# std          21.768636   226.579864  ...    4.563925    4.440823
# min          91.669998   290.790009  ...   61.705482   59.507275
# 25%         110.220003   539.342514  ...   74.568525   72.058861
# 50%         119.889999   729.779999  ...   77.141674   74.779228
# 75%         142.455002   891.134979  ...   79.135523   77.651459
# max         177.199997  1213.410034  ...   88.837830   84.557114
#
# [8 rows x 168 columns]

# %%
panel_data.head()
# Out:
# Attributes        High                         ...  Adj Close
# Symbols           AAPL        AMZN        AXP  ...        VLO        WBA        XOM
# Date                                           ...
# 2014-12-31  113.129997  312.980011  94.750000  ...  42.065907  69.451050  78.086937
# 2015-01-02  111.440002  314.750000  93.940002  ...  42.779743  69.268761  78.407913
# 2015-01-05  108.650002  308.380005  92.779999  ...  41.020634  67.901611  76.262527
# 2015-01-06  107.430000  303.000000  90.900002  ...  40.519245  68.074776  75.857101
# 2015-01-07  108.199997  301.279999  91.010002  ...  40.204807  69.815613  76.625732
#
# [5 rows x 168 columns]

# %%
panel_data.columns.tolist()
# Out:
# [('High', 'AAPL'),
#  ('High', 'AMZN'),
#  ('High', 'AXP'),
#  ('High', 'BA'),
#  ('High', 'BAC'),
#  ('High', 'CVX'),
#  ('High', 'F'),
#  ('High', 'GE'),
#  ('High', 'HMC'),
#  ('High', 'IBM'),
#  ('High', 'INTC'),
#  ('High', 'JNJ'),
#  ('High', 'KO'),
#  ('High', 'LMT'),
#  ('High', 'MA'),
#  ('High', 'MCD'),
#  ('High', 'MSBHY'),
#  ('High', 'MSFT'),
#  ('High', 'NAV'),
#  ('High', 'NOC'),
#  ('High', 'PEP'),
#  ('High', 'SNE'),
#  ('High', 'SYNC'),
#  ('High', 'TM'),
#  ('High', 'TXN'),
#  ('High', 'VLO'),
#  ('High', 'WBA'),
#  ('High', 'XOM'),
#  ('Low', 'AAPL'),
#  ('Low', 'AMZN'),
#  ('Low', 'AXP'),
#  ('Low', 'BA'),
#  ('Low', 'BAC'),
#  ('Low', 'CVX'),
#  ('Low', 'F'),
#  ('Low', 'GE'),
#  ('Low', 'HMC'),
#  ('Low', 'IBM'),
#  ('Low', 'INTC'),
#  ('Low', 'JNJ'),
#  ('Low', 'KO'),
#  ('Low', 'LMT'),
#  ('Low', 'MA'),
#  ('Low', 'MCD'),
#  ('Low', 'MSBHY'),
#  ('Low', 'MSFT'),
#  ('Low', 'NAV'),
#  ('Low', 'NOC'),
#  ('Low', 'PEP'),
#  ('Low', 'SNE'),
#  ('Low', 'SYNC'),
#  ('Low', 'TM'),
#  ('Low', 'TXN'),
#  ('Low', 'VLO'),
#  ('Low', 'WBA'),
#  ('Low', 'XOM'),
#  ('Open', 'AAPL'),
#  ('Open', 'AMZN'),
#  ('Open', 'AXP'),
#  ('Open', 'BA'),
#  ('Open', 'BAC'),
#  ('Open', 'CVX'),
#  ('Open', 'F'),
#  ('Open', 'GE'),
#  ('Open', 'HMC'),
#  ('Open', 'IBM'),
#  ('Open', 'INTC'),
#  ('Open', 'JNJ'),
#  ('Open', 'KO'),
#  ('Open', 'LMT'),
#  ('Open', 'MA'),
#  ('Open', 'MCD'),
#  ('Open', 'MSBHY'),
#  ('Open', 'MSFT'),
#  ('Open', 'NAV'),
#  ('Open', 'NOC'),
#  ('Open', 'PEP'),
#  ('Open', 'SNE'),
#  ('Open', 'SYNC'),
#  ('Open', 'TM'),
#  ('Open', 'TXN'),
#  ('Open', 'VLO'),
#  ('Open', 'WBA'),
#  ('Open', 'XOM'),
#  ('Close', 'AAPL'),
#  ('Close', 'AMZN'),
#  ('Close', 'AXP'),
#  ('Close', 'BA'),
#  ('Close', 'BAC'),
#  ('Close', 'CVX'),
#  ('Close', 'F'),
#  ('Close', 'GE'),
#  ('Close', 'HMC'),
#  ('Close', 'IBM'),
#  ('Close', 'INTC'),
#  ('Close', 'JNJ'),
#  ('Close', 'KO'),
#  ('Close', 'LMT'),
#  ('Close', 'MA'),
#  ('Close', 'MCD'),
#  ('Close', 'MSBHY'),
#  ('Close', 'MSFT'),
#  ('Close', 'NAV'),
#  ('Close', 'NOC'),
#  ('Close', 'PEP'),
#  ('Close', 'SNE'),
#  ('Close', 'SYNC'),
#  ('Close', 'TM'),
#  ('Close', 'TXN'),
#  ('Close', 'VLO'),
#  ('Close', 'WBA'),
#  ('Close', 'XOM'),
#  ('Volume', 'AAPL'),
#  ('Volume', 'AMZN'),
#  ('Volume', 'AXP'),
#  ('Volume', 'BA'),
#  ('Volume', 'BAC'),
#  ('Volume', 'CVX'),
#  ('Volume', 'F'),
#  ('Volume', 'GE'),
#  ('Volume', 'HMC'),
#  ('Volume', 'IBM'),
#  ('Volume', 'INTC'),
#  ('Volume', 'JNJ'),
#  ('Volume', 'KO'),
#  ('Volume', 'LMT'),
#  ('Volume', 'MA'),
#  ('Volume', 'MCD'),
#  ('Volume', 'MSBHY'),
#  ('Volume', 'MSFT'),
#  ('Volume', 'NAV'),
#  ('Volume', 'NOC'),
#  ('Volume', 'PEP'),
#  ('Volume', 'SNE'),
#  ('Volume', 'SYNC'),
#  ('Volume', 'TM'),
#  ('Volume', 'TXN'),
#  ('Volume', 'VLO'),
#  ('Volume', 'WBA'),
#  ('Volume', 'XOM'),
#  ('Adj Close', 'AAPL'),
#  ('Adj Close', 'AMZN'),
#  ('Adj Close', 'AXP'),
#  ('Adj Close', 'BA'),
#  ('Adj Close', 'BAC'),
#  ('Adj Close', 'CVX'),
#  ('Adj Close', 'F'),
#  ('Adj Close', 'GE'),
#  ('Adj Close', 'HMC'),
#  ('Adj Close', 'IBM'),
#  ('Adj Close', 'INTC'),
#  ('Adj Close', 'JNJ'),
#  ('Adj Close', 'KO'),
#  ('Adj Close', 'LMT'),
#  ('Adj Close', 'MA'),
#  ('Adj Close', 'MCD'),
#  ('Adj Close', 'MSBHY'),
#  ('Adj Close', 'MSFT'),
#  ('Adj Close', 'NAV'),
#  ('Adj Close', 'NOC'),
#  ('Adj Close', 'PEP'),
#  ('Adj Close', 'SNE'),
#  ('Adj Close', 'SYNC'),
#  ('Adj Close', 'TM'),
#  ('Adj Close', 'TXN'),
#  ('Adj Close', 'VLO'),
#  ('Adj Close', 'WBA'),
#  ('Adj Close', 'XOM')]

# %%
stock_close = panel_data[['Close']]
stock_open = panel_data[['Open']]
print(stock_close.iloc[0])
# Out:
# Attributes  Symbols
# Close       AAPL       110.379997
#             AMZN       310.350006
#             AXP         93.040001
#             BA         129.979996
#             BAC         17.889999
#             CVX        112.180000
#             F           15.500000
#             GE          24.298077
#             HMC         29.520000
#             IBM        160.440002
#             INTC        36.290001
#             JNJ        104.570000
#             KO          42.220001
#             LMT        192.570007
#             MA          86.160004
#             MCD         93.699997
#             MSBHY       36.759998
#             MSFT        46.450001
#             NAV         33.480000
#             NOC        147.389999
#             PEP         94.559998
#             SNE         20.469999
#             SYNC         2.000000
#             TM         125.480003
#             TXN         53.470001
#             VLO         49.500000
#             WBA         76.199997
#             XOM         92.449997
# Name: 2014-12-31 00:00:00, dtype: float64

# %%
# Calculate daily stock movement
stock_close = np.array(stock_close).T
stock_open = np.array(stock_open).T
row,col = stock_close.shape
print(row, col)
movements = np.zeros([row,col])
for i in range(0,row):
    movements[i,:] = np.subtract(stock_close[i,:],stock_open[i,:])
# Out:
# 28 756

# %%
for i in range(len(companies)):
    print('Company: {}, movement: {} '.format(companies[i][0],sum(movements[i,:])))
# Out:
# Company: Apple, movement: 14.249893188476562
# Company: Amazon, movement: -83.93020629882812
# Company: American Express, movement: 5.600105285644531
# Company: Boeing, movement: 100.44984436035156
# Company: Bank of America, movement: -3.780003547668457
# Company: Chevron, movement: 27.099990844726562
# Company: Ford, movement: -5.559996604919434
# Company: General Electrics, movement: 4.509649276733398
# Company: Honda, movement: -8.180000305175781
# Company: IBM, movement: 15.669967651367188
# Company: Intel, movement: 19.52003288269043
# Company: Johnson & Johnson, movement: 30.619949340820312
# Company: Coca Cola, movement: 11.459976196289062
# Company: Lockheed Martin, movement: 57.899932861328125
# Company: MasterCard, movement: 23.569869995117188
# Company: McDonalds, movement: 51.290016174316406
# Company: Mistubishi, movement: 30.440019607543945
# Company: Microsoft, movement: 28.480026245117188
# Company: Navistar, movement: -0.6599926948547363
# Company: Northrom Grumman, movement: 72.03007507324219
# Company: Pepsi, movement: 36.96997833251953
# Company: Sony, movement: -0.4999885559082031
# Company: Symantec, movement: 0.8499988317489624
# Company: Toyata, movement: -17.430099487304688
# Company: Texas Instruments, movement: 28.409912109375
# Company: Valero Energy, movement: 29.399993896484375
# Company: Walgreen, movement: -5.940071105957031
# Company: Exxon, movement: 9.929985046386719
